# %% [markdown]
# # 在 HDF5 中探索 CelebA 数据——人脸
#
# PyTorch 生成对抗式网络编程, 2020

# %% [markdown]
# ## 探索 HDF5 数据

# %%
import h5py

import numpy
import matplotlib.pyplot as plt

# %%
with h5py.File('datasets/celeba_aligned_small.h5py', 'r') as file_object:
  
  for group in file_object:
    print(group)
    pass
# Out:
# img_align_celeba

# %%
# 打开 HDF5 文件，提取和绘制样本图像

with h5py.File('datasets/celeba_aligned_small.h5py', 'r') as file_object:
  dataset = file_object['img_align_celeba']
  image = numpy.array(dataset['6.jpg'])
  plt.imshow(image, interpolation='none')
  pass

# %%
#shape of the image array

image.shape
# Out:
# (218, 178, 3)
